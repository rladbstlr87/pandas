# %%
import numpy as np
import pandas as pd

# %%
# 엑셀 파일 경로
file = "data/DAMF2.xlsx"

# %%
excel = pd.read_excel(file)

# %%
excel[['이름', 'github']]
# Out:
#      이름          github
# 0   오창희         5chang2
# 1   권기남          kka712
# 2   김광성         kgs3770
# 3   김승현         wnshite
# 4   김윤식     rladbstlr87
# 5   김주성       darkmonke
# 6   민예린    Yerineeeee98
# 7   박선민      manimo1234
# 8   박소리         alslsol
# 9   박수빈     vivianpark8
# 10  박수현       iam-Aerin
# 11  신효진        DSVIT100
# 12  양다희        dahee325
# 13  이유진         eyoojin
# 14  이주현        Lejuhyun
# 15  임서영    seoyoung1203
# 16  장윤서  jangyunseo4547
# 17  조중석     Chojungseok
# 18  최민혁    Minhyeok0330
# 19  최시언       choisieon
# 20  황다인        dain0628
# 21  황성진    seongjin5743

# %%
excel.head() # 구조를 볼때 쓰며 맨앞 5개 자료만 보여준다
# Out:
#     이름       전공                  email       github
# 0  오창희  소프트웨어공학     oche.edu@gmail.com      5chang2
# 1  권기남   항공전기전공     rlska213@naver.com       kka712
# 2  김광성     경제학과      kgs3770@gmail.com      kgs3770
# 3  김승현     음악학과  tmdgus_skfk@naver.com      wnshite
# 4  김윤식   중국통상학과     manylong@naver.com  rladbstlr87

# %%
excel = pd.read_excel(file, sheet_name='menu')
excel.head()
# Out:
#         가게이름   시간                       메뉴  \
# 0     독립문설렁탕   5분                  설랑탕/불고기
# 1        송준옥   8분                 맑은뼈국(국밥)
# 2       종로김밥  NaN                       분식
# 3  바지락수제비칼국수   8분               수제비,칼국수,김밥
# 4      유닭스토리   3분  닭(칼국수, 곰탕, 계장)\n닭갈비치즈덮밥
#
#                                                  한줄평
# 0                             설렁탕이 6천원! / 하지만 웨이팅 있음
# 1  보통11,000원/특14,000원 bar형식의 테이블로 3~4명가면 일렬로 앉아야되...
# 2            2/12 방문기준 신촌역점은 영업 안했어요! 신촌로터리점은 안가봤어요!
# 3  칼국수, 수제비, 칼제비 5,000원 김밥 3,000원 / 자리가 협소해서 2-3팀...
# 4                               10,000~11,000원/자리많아요

# %%
excel = pd.read_excel(file, sheet_name=None)
excel.head()  # 여러개는 안됨?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 excel = pd.read_excel(file, sheet_name=None)
# ----> 2 excel.head()  # 여러개는 안됨?
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
menu_df = excel[['가게이름', '메뉴']]
menu_df
# Out:
#         가게이름                       메뉴
# 0     독립문설렁탕                  설랑탕/불고기
# 1        송준옥                 맑은뼈국(국밥)
# 2       종로김밥                       분식
# 3  바지락수제비칼국수               수제비,칼국수,김밥
# 4      유닭스토리  닭(칼국수, 곰탕, 계장)\n닭갈비치즈덮밥
# 5      별당김치찜                김치찜, 제육볶음
# 6      꼬숑돈까스                      돈까스
# 7    포가레 쌀국수                      NaN

# %%
menu_df.to_excel('data/sample.xlsx', index=False) # 파일 수정해서 생성

# %% [markdown]
# # CSV

# %%
file2 = "data/DAMF2.csv"

# %%
df = pd.read_csv(file2)

# %%
df2 = df[['이름', 'email']]
df2.to_csv('data/sample.csv') # 파일 수정해서 생성
